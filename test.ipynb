# %% [markdown]
# <a href="https://colab.research.google.com/github/jmeenigams/test-colab/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello GIT")
# Out:
# Hello GIT

# %%
print("Hello Collob")
# Out:
# Hello Collob
